# %%
import requests
import tarfile
import os

data_types = {
    "10-Day": "lakes.TPJOJ.2.txt.tar.gz",
    "27A-Day": "lakes.27a.2.txt.tar.gz",
    "27B-Day": "lakes.27b.2.txt.tar.gz",
    "35-Day": "lakes.35d.2.txt.tar.gz"
}
base_url = "https://ipad.fas.usda.gov/lakes/images/"

def select_data_type():
    print("Select data type to download:")
    for i, key in enumerate(data_types.keys(), 1):
        print(f"{i}. {key}")
    choice = int(input("Enter option number (1-4): "))
    keys = list(data_types.keys())
    selected = keys[choice - 1]
    print(f"Selected: {selected}")
    return data_types[selected], selected

def download_file(url, filename):
    print(f"Downloading from {url} ...")
    response = requests.get(url, stream=True)
    response.raise_for_status()
    with open(filename, "wb") as f:
        for chunk in response.iter_content(chunk_size=8192):
            f.write(chunk)
    print(f"Downloaded to {filename}")

def extract_tar_gz(tar_path, extract_folder):
    print(f"Extracting {tar_path} ...")
    with tarfile.open(tar_path, "r:gz") as tar:
        tar.extractall(path=extract_folder)
    print(f"Extracted to {extract_folder}")

def print_extracted_files(folder):
    print("\nExtracted files:")
    for root, dirs, files in os.walk(folder):
        for file in files:
            print(os.path.join(root, file))

def read_main_txt(folder):
    for file in os.listdir(folder):
        if file.endswith(".txt"):
            file_path = os.path.join(folder, file)
            with open(file_path, encoding="utf-8") as f:
                lines = f.readlines()
                print(f"\nFirst 10 lines of {file_path}:")
                print("".join(lines[:10]))
            break

if __name__ == "__main__":
    tar_name, data_type_str = select_data_type()
    url = base_url + tar_name
    local_tar_path = tar_name
    output_folder = f"lake_data_{data_type_str.replace('-','').replace(' ','')}"
    download_file(url, local_tar_path)
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    extract_tar_gz(local_tar_path, output_folder)
    print_extracted_files(output_folder)
    read_main_txt(output_folder)
# Out:
# Select data type to download:
# 1. 10-Day
# 2. 27A-Day
# 3. 27B-Day
# 4. 35-Day
# Selected: 35-Day
# Downloading from https://ipad.fas.usda.gov/lakes/images/lakes.35d.2.txt.tar.gz ...
# Downloaded to lakes.35d.2.txt.tar.gz
# Extracting lakes.35d.2.txt.tar.gz ...
# Extracted to lake_data_35Day
#
# Extracted files:
# lake_data_35Day\lake000043.35d.2.txt
# lake_data_35Day\lake000067.35d.2.txt
# lake_data_35Day\lake000073.35d.2.txt
# lake_data_35Day\lake000079.35d.2.txt
# lake_data_35Day\lake000085.35d.2.txt
# lake_data_35Day\lake000087.35d.2.txt
# lake_data_35Day\lake000097.35d.2.txt
# lake_data_35Day\lake000356.35d.2.txt
# lake_data_35Day\lake000387.35d.2.txt
# lake_data_35Day\lake000468.35d.2.txt
# lake_data_35Day\lake000496.35d.2.txt
# lake_data_35Day\lake000525.35d.2.txt
# lake_data_35Day\lake000526.35d.2.txt
# lake_data_35Day\lake000680.35d.2.txt
# lake_data_35Day\lake000762.35d.2.txt
# lake_data_35Day\lake000773.35d.2.txt
# lake_data_35Day\lake000787.35d.2.txt
# lake_data_35Day\lake000955.35d.2.txt
# lake_data_35Day\lake001164.35d.2.txt
# lake_data_35Day\lake001273.35d.2.txt
# lake_data_35Day\lake001278.35d.2.txt
# lake_data_35Day\lake001279.35d.2.txt
# lake_data_35Day\lake001432.35d.2.txt
# lake_data_35Day\lake001478.35d.2.txt
# lake_data_35Day\lake001547.35d.2.txt
# lake_data_35Day\lake001568.35d.2.txt
# lake_data_35Day\lake001577.35d.2.txt
# lake_data_35Day\lake001602.35d.2.txt
# lake_data_35Day\lake001603.35d.2.txt
# lake_data_35Day\lake001712.35d.2.txt
# lake_data_35Day\lake001861.35d.2.txt
# lake_data_35Day\lake001905.35d.2.txt
# lake_data_35Day\lake001922.35d.2.txt
# lake_data_35Day\lake002280.35d.2.txt
# lake_data_35Day\lake002328.35d.2.txt
# lake_data_35Day\lake002329.35d.2.txt
# lake_data_35Day\lake003908.35d.2.txt
# lake_data_35Day\lake003910.35d.2.txt
# lake_data_35Day\lake004190.35d.2.txt
# lake_data_35Day\lake004286.35d.2.txt
# lake_data_35Day\lake005992.35d.2.txt
# lake_data_35Day\lake100461.35d.2.txt
# lake_data_35Day\lake101437.35d.2.txt
# lake_data_35Day\lake101438.35d.2.txt
# lake_data_35Day\lake101495.35d.2.txt
#
# First 10 lines of lake_data_35Day\lake000043.35d.2.txt:
# ENV.2.1                    : Data Processing Version ID
# 000043 Cardiel             : Target database id number and name
# -48.910 288.670            : Latitude and longitude (degrees East) of target mid-point
# -48.970 -48.874            : Latitude range of pass traversing target at which data is accepted
#  65      32                : Satellite pass and revolution number designation
#          24                : Reference pass derived from ENVISAT cycle #
#           1                : Reference pass tracker mode (ocean=0, ice1=1, ice2=2, sea ice=3)
#   N/A                      : N/A Bias
#   N/A                      : N/A Bias
#   N/A                      : N/A Bias

# %%
import requests
import tarfile
import os

# ------------------ NEW NASA DATA SOURCES ------------------
DATASETS = {
    "Lake 10-day": "https://earth.gsfc.nasa.gov/gwm/zip/lake.10.tar.gz",
    "Lake 30-day": "https://earth.gsfc.nasa.gov/gwm/zip/lake.30.tar.gz",
    "Extent 10-day": "https://earth.gsfc.nasa.gov/gwm/zip/extent.10.tar.gz"
}

# ------------------ SELECT DATA ------------------
def select_dataset():
    print("Available NASA GWM datasets:\n")

    for i, key in enumerate(DATASETS.keys(), 1):
        print(f"{i}. {key}")

    choice = int(input("\nSelect dataset (1-3): "))
    selected_key = list(DATASETS.keys())[choice - 1]

    print(f"\nSelected: {selected_key}")
    return selected_key, DATASETS[selected_key]

# ------------------ DOWNLOAD ------------------
def download_file(url, output_path):
    print(f"\nDownloading from:\n{url}")

    response = requests.get(url, stream=True)
    response.raise_for_status()

    with open(output_path, "wb") as f:
        for chunk in response.iter_content(chunk_size=8192):
            if chunk:
                f.write(chunk)

    print(f"Saved to: {output_path}")

# ------------------ EXTRACT ------------------
def extract_tar_gz(file_path, output_folder):
    print(f"\nExtracting {file_path} ...")

    with tarfile.open(file_path, "r:gz") as tar:
        tar.extractall(path=output_folder)

    print(f"Extracted to: {output_folder}")

# ------------------ INSPECT FILES ------------------
def list_files(folder):
    print("\nExtracted files:")

    for root, _, files in os.walk(folder):
        for file in files:
            print(os.path.join(root, file))

# ------------------ PREVIEW DATA ------------------
def preview_txt(folder):
    print("\nPreview (first TXT file):")

    for file in os.listdir(folder):
        if file.endswith(".txt"):
            path = os.path.join(folder, file)

            with open(path, encoding="utf-8", errors="ignore") as f:
                lines = f.readlines()

            print(f"\nFile: {path}\n")
            print("".join(lines[:10]))
            break

# ------------------ MAIN ------------------
if __name__ == "__main__":

    dataset_name, url = select_dataset()

    output_tar = url.split("/")[-1]
    output_folder = f"nasa_gwm_{dataset_name.lower().replace(' ', '_')}"

    os.makedirs(output_folder, exist_ok=True)

    # download
    download_file(url, output_tar)

    # extract
    extract_tar_gz(output_tar, output_folder)

    # inspect
    list_files(output_folder)

    # preview
    preview_txt(output_folder)
# Out:
# Available NASA GWM datasets:
#
# 1. Lake 10-day
# 2. Lake 30-day
# 3. Extent 10-day
#
# Selected: Lake 30-day
#
# Downloading from:
# https://earth.gsfc.nasa.gov/gwm/zip/lake.30.tar.gz
# Saved to: lake.30.tar.gz
#
# Extracting lake.30.tar.gz ...
# Extracted to: nasa_gwm_lake_30-day
#
# Extracted files:
# nasa_gwm_lake_30-day\lake000004.27a.2.jpg
# nasa_gwm_lake_30-day\lake000004.27a.2.txt
# nasa_gwm_lake_30-day\lake000008.27b.2.jpg
# nasa_gwm_lake_30-day\lake000008.27b.2.txt
# nasa_gwm_lake_30-day\lake000010.27b.2.jpg
# nasa_gwm_lake_30-day\lake000010.27b.2.txt
# nasa_gwm_lake_30-day\lake000038.27a.2.jpg
# nasa_gwm_lake_30-day\lake000038.27a.2.txt
# nasa_gwm_lake_30-day\lake000043.35d.2.jpg
# nasa_gwm_lake_30-day\lake000043.35d.2.txt
# nasa_gwm_lake_30-day\lake000047.27b.2.jpg
# nasa_gwm_lake_30-day\lake000047.27b.2.txt
# nasa_gwm_lake_30-day\lake000055.27b.2.jpg
# nasa_gwm_lake_30-day\lake000055.27b.2.txt
# nasa_gwm_lake_30-day\lake000060.27b.2.jpg
# nasa_gwm_lake_30-day\lake000060.27b.2.txt
# nasa_gwm_lake_30-day\lake000061.27b.2.jpg
# nasa_gwm_lake_30-day\lake000061.27b.2.txt
# nasa_gwm_lake_30-day\lake000062.27b.2.jpg
# nasa_gwm_lake_30-day\lake000062.27b.2.txt
# nasa_gwm_lake_30-day\lake000066.27b.2.jpg
# nasa_gwm_lake_30-day\lake000066.27b.2.txt
# nasa_gwm_lake_30-day\lake000067.35d.2.jpg
# nasa_gwm_lake_30-day\lake000067.35d.2.txt
# nasa_gwm_lake_30-day\lake000069.27a.2.jpg
# nasa_gwm_lake_30-day\lake000069.27a.2.txt
# nasa_gwm_lake_30-day\lake000070.27b.2.jpg
# nasa_gwm_lake_30-day\lake000070.27b.2.txt
# nasa_gwm_lake_30-day\lake000071.27a.2.jpg
# nasa_gwm_lake_30-day\lake000071.27a.2.txt
# nasa_gwm_lake_30-day\lake000072.27a.2.jpg
# nasa_gwm_lake_30-day\lake000072.27a.2.txt
# nasa_gwm_lake_30-day\lake000073.35d.2.jpg
# nasa_gwm_lake_30-day\lake000073.35d.2.txt
# nasa_gwm_lake_30-day\lake000074.27b.2.jpg
# nasa_gwm_lake_30-day\lake000074.27b.2.txt
# nasa_gwm_lake_30-day\lake000075.27a.2.jpg
# nasa_gwm_lake_30-day\lake000075.27a.2.txt
# nasa_gwm_lake_30-day\lake000077.27a.2.jpg
# nasa_gwm_lake_30-day\lake000077.27a.2.txt
# nasa_gwm_lake_30-day\lake000078.27b.2.jpg
# nasa_gwm_lake_30-day\lake000078.27b.2.txt
# nasa_gwm_lake_30-day\lake000079.35d.2.jpg
# nasa_gwm_lake_30-day\lake000079.35d.2.txt
# nasa_gwm_lake_30-day\lake000083.27b.2.jpg
# nasa_gwm_lake_30-day\lake000083.27b.2.txt
# nasa_gwm_lake_30-day\lake000084.27b.2.jpg
# nasa_gwm_lake_30-day\lake000084.27b.2.txt
# nasa_gwm_lake_30-day\lake000085.35d.2.jpg
# nasa_gwm_lake_30-day\lake000085.35d.2.txt
# nasa_gwm_lake_30-day\lake000087.35d.2.jpg
# nasa_gwm_lake_30-day\lake000087.35d.2.txt
# nasa_gwm_lake_30-day\lake000089.27a.2.jpg
# nasa_gwm_lake_30-day\lake000089.27a.2.txt
# nasa_gwm_lake_30-day\lake000090.27a.2.jpg
# nasa_gwm_lake_30-day\lake000090.27a.2.txt
# nasa_gwm_lake_30-day\lake000092.27b.2.jpg
# nasa_gwm_lake_30-day\lake000092.27b.2.txt
# nasa_gwm_lake_30-day\lake000095.27b.2.jpg
# nasa_gwm_lake_30-day\lake000095.27b.2.txt
# nasa_gwm_lake_30-day\lake000097.35d.2.jpg
# nasa_gwm_lake_30-day\lake000097.35d.2.txt
# nasa_gwm_lake_30-day\lake000100.27b.2.jpg
# nasa_gwm_lake_30-day\lake000100.27b.2.txt
# nasa_gwm_lake_30-day\lake000104.27b.2.jpg
# nasa_gwm_lake_30-day\lake000104.27b.2.txt
# nasa_gwm_lake_30-day\lake000106.27b.2.jpg
# nasa_gwm_lake_30-day\lake000106.27b.2.txt
# nasa_gwm_lake_30-day\lake000109.27b.2.jpg
# nasa_gwm_lake_30-day\lake000109.27b.2.txt
# nasa_gwm_lake_30-day\lake000110.27b.2.jpg
# nasa_gwm_lake_30-day\lake000110.27b.2.txt
# nasa_gwm_lake_30-day\lake000114.27b.2.jpg
# nasa_gwm_lake_30-day\lake000114.27b.2.txt
# nasa_gwm_lake_30-day\lake000116.27a.2.jpg
# nasa_gwm_lake_30-day\lake000116.27a.2.txt
# nasa_gwm_lake_30-day\lake000119.27a.2.jpg
# nasa_gwm_lake_30-day\lake000119.27a.2.txt
# nasa_gwm_lake_30-day\lake000260.27a.2.jpg
# nasa_gwm_lake_30-day\lake000260.27a.2.txt
# nasa_gwm_lake_30-day\lake000265.27a.2.jpg
# nasa_gwm_lake_30-day\lake000265.27a.2.txt
# nasa_gwm_lake_30-day\lake000267.27b.2.jpg
# nasa_gwm_lake_30-day\lake000267.27b.2.txt
# nasa_gwm_lake_30-day\lake000292.27b.2.jpg
# nasa_gwm_lake_30-day\lake000292.27b.2.txt
# nasa_gwm_lake_30-day\lake000318.27a.2.jpg
# nasa_gwm_lake_30-day\lake000318.27a.2.txt
# nasa_gwm_lake_30-day\lake000339.27b.2.jpg
# nasa_gwm_lake_30-day\lake000339.27b.2.txt
# nasa_gwm_lake_30-day\lake000356.35d.2.jpg
# nasa_gwm_lake_30-day\lake000356.35d.2.txt
# nasa_gwm_lake_30-day\lake000361.27a.2.jpg
# nasa_gwm_lake_30-day\lake000361.27a.2.txt
# nasa_gwm_lake_30-day\lake000371.27a.2.jpg
# nasa_gwm_lake_30-day\lake000371.27a.2.txt
# nasa_gwm_lake_30-day\lake000373.27b.2.jpg
# nasa_gwm_lake_30-day\lake000373.27b.2.txt
# nasa_gwm_lake_30-day\lake000387.35d.2.jpg
# nasa_gwm_lake_30-day\lake000387.35d.2.txt
# nasa_gwm_lake_30-day\lake000388.27b.2.jpg
# nasa_gwm_lake_30-day\lake000388.27b.2.txt
# nasa_gwm_lake_30-day\lake000390.27a.2.jpg
# nasa_gwm_lake_30-day\lake000390.27a.2.txt
# nasa_gwm_lake_30-day\lake000404.27b.2.jpg
# nasa_gwm_lake_30-day\lake000404.27b.2.txt
# nasa_gwm_lake_30-day\lake000405.27a.2.jpg
# nasa_gwm_lake_30-day\lake000405.27a.2.txt
# nasa_gwm_lake_30-day\lake000419.27a.2.jpg
# nasa_gwm_lake_30-day\lake000419.27a.2.txt
# nasa_gwm_lake_30-day\lake000461.27a.2.jpg
# nasa_gwm_lake_30-day\lake000461.27a.2.txt
# nasa_gwm_lake_30-day\lake000463.27b.2.jpg
# nasa_gwm_lake_30-day\lake000463.27b.2.txt
# nasa_gwm_lake_30-day\lake000468.35d.2.jpg
# nasa_gwm_lake_30-day\lake000468.35d.2.txt
# nasa_gwm_lake_30-day\lake000478.27b.2.jpg
# nasa_gwm_lake_30-day\lake000478.27b.2.txt
# nasa_gwm_lake_30-day\lake000496.35d.2.jpg
# nasa_gwm_lake_30-day\lake000496.35d.2.txt
# nasa_gwm_lake_30-day\lake000516.27a.2.jpg
# nasa_gwm_lake_30-day\lake000516.27a.2.txt
# nasa_gwm_lake_30-day\lake000522.27a.2.jpg
# nasa_gwm_lake_30-day\lake000522.27a.2.txt
# nasa_gwm_lake_30-day\lake000523.27a.2.jpg
# nasa_gwm_lake_30-day\lake000523.27a.2.txt
# nasa_gwm_lake_30-day\lake000524.27a.2.jpg
# nasa_gwm_lake_30-day\lake000524.27a.2.txt
# nasa_gwm_lake_30-day\lake000525.35d.2.jpg
# nasa_gwm_lake_30-day\lake000525.35d.2.txt
# nasa_gwm_lake_30-day\lake000526.35d.2.jpg
# nasa_gwm_lake_30-day\lake000526.35d.2.txt
# nasa_gwm_lake_30-day\lake000527.27a.2.jpg
# nasa_gwm_lake_30-day\lake000527.27a.2.txt
# nasa_gwm_lake_30-day\lake000528.27a.2.jpg
# nasa_gwm_lake_30-day\lake000528.27a.2.txt
# nasa_gwm_lake_30-day\lake000533.27b.2.jpg
# nasa_gwm_lake_30-day\lake000533.27b.2.txt
# nasa_gwm_lake_30-day\lake000535.27a.2.jpg
# nasa_gwm_lake_30-day\lake000535.27a.2.txt
# nasa_gwm_lake_30-day\lake000536.27b.2.jpg
# nasa_gwm_lake_30-day\lake000536.27b.2.txt
# nasa_gwm_lake_30-day\lake000537.27b.2.jpg
# nasa_gwm_lake_30-day\lake000537.27b.2.txt
# nasa_gwm_lake_30-day\lake000538.27a.2.jpg
# nasa_gwm_lake_30-day\lake000538.27a.2.txt
# nasa_gwm_lake_30-day\lake000541.27b.2.jpg
# nasa_gwm_lake_30-day\lake000541.27b.2.txt
# nasa_gwm_lake_30-day\lake000542.27a.2.jpg
# nasa_gwm_lake_30-day\lake000542.27a.2.txt
# nasa_gwm_lake_30-day\lake000544.21d.2.jpg
# nasa_gwm_lake_30-day\lake000544.21d.2.txt
# nasa_gwm_lake_30-day\lake000546.27a.2.jpg
# nasa_gwm_lake_30-day\lake000546.27a.2.txt
# nasa_gwm_lake_30-day\lake000547.21d.2.jpg
# nasa_gwm_lake_30-day\lake000547.21d.2.txt
# nasa_gwm_lake_30-day\lake000548.27b.2.jpg
# nasa_gwm_lake_30-day\lake000548.27b.2.txt
# nasa_gwm_lake_30-day\lake000549.27b.2.jpg
# nasa_gwm_lake_30-day\lake000549.27b.2.txt
# nasa_gwm_lake_30-day\lake000550.27a.2.jpg
# nasa_gwm_lake_30-day\lake000550.27a.2.txt
# nasa_gwm_lake_30-day\lake000551.27a.2.jpg
# nasa_gwm_lake_30-day\lake000551.27a.2.txt
# nasa_gwm_lake_30-day\lake000552.27a.2.jpg
# nasa_gwm_lake_30-day\lake000552.27a.2.txt
# nasa_gwm_lake_30-day\lake000553.27b.2.jpg
# nasa_gwm_lake_30-day\lake000553.27b.2.txt
# nasa_gwm_lake_30-day\lake000554.27b.2.jpg
# nasa_gwm_lake_30-day\lake000554.27b.2.txt
# nasa_gwm_lake_30-day\lake000560.27a.2.jpg
# nasa_gwm_lake_30-day\lake000560.27a.2.txt
# nasa_gwm_lake_30-day\lake000562.21d.2.jpg
# nasa_gwm_lake_30-day\lake000562.21d.2.txt
# nasa_gwm_lake_30-day\lake000564.27a.2.jpg
# nasa_gwm_lake_30-day\lake000564.27a.2.txt
# nasa_gwm_lake_30-day\lake000566.27b.2.jpg
# nasa_gwm_lake_30-day\lake000566.27b.2.txt
# nasa_gwm_lake_30-day\lake000568.27a.2.jpg
# nasa_gwm_lake_30-day\lake000568.27a.2.txt
# nasa_gwm_lake_30-day\lake000574.27b.2.jpg
# nasa_gwm_lake_30-day\lake000574.27b.2.txt
# nasa_gwm_lake_30-day\lake000580.27a.2.jpg
# nasa_gwm_lake_30-day\lake000580.27a.2.txt
# nasa_gwm_lake_30-day\lake000594.27a.2.jpg
# nasa_gwm_lake_30-day\lake000594.27a.2.txt
# nasa_gwm_lake_30-day\lake000609.27a.2.jpg
# nasa_gwm_lake_30-day\lake000609.27a.2.txt
# nasa_gwm_lake_30-day\lake000626.27b.2.jpg
# nasa_gwm_lake_30-day\lake000626.27b.2.txt
# nasa_gwm_lake_30-day\lake000642.27a.2.jpg
# nasa_gwm_lake_30-day\lake000642.27a.2.txt
# nasa_gwm_lake_30-day\lake000658.27b.2.jpg
# nasa_gwm_lake_30-day\lake000658.27b.2.txt
# nasa_gwm_lake_30-day\lake000665.21d.2.jpg
# nasa_gwm_lake_30-day\lake000665.21d.2.txt
# nasa_gwm_lake_30-day\lake000677.27b.2.jpg
# nasa_gwm_lake_30-day\lake000677.27b.2.txt
# nasa_gwm_lake_30-day\lake000680.35d.2.jpg
# nasa_gwm_lake_30-day\lake000680.35d.2.txt
# nasa_gwm_lake_30-day\lake000701.21d.2.jpg
# nasa_gwm_lake_30-day\lake000701.21d.2.txt
# nasa_gwm_lake_30-day\lake000703.27a.2.jpg
# nasa_gwm_lake_30-day\lake000703.27a.2.txt
# nasa_gwm_lake_30-day\lake000705.27b.2.jpg
# nasa_gwm_lake_30-day\lake000705.27b.2.txt
# nasa_gwm_lake_30-day\lake000707.27a.2.jpg
# nasa_gwm_lake_30-day\lake000707.27a.2.txt
# nasa_gwm_lake_30-day\lake000714.27a.2.jpg
# nasa_gwm_lake_30-day\lake000714.27a.2.txt
# nasa_gwm_lake_30-day\lake000718.27b.2.jpg
# nasa_gwm_lake_30-day\lake000718.27b.2.txt
# nasa_gwm_lake_30-day\lake000723.27a.2.jpg
# nasa_gwm_lake_30-day\lake000723.27a.2.txt
# nasa_gwm_lake_30-day\lake000731.27b.2.jpg
# nasa_gwm_lake_30-day\lake000731.27b.2.txt
# nasa_gwm_lake_30-day\lake000762.35d.2.jpg
# nasa_gwm_lake_30-day\lake000762.35d.2.txt
# nasa_gwm_lake_30-day\lake000769.27b.2.jpg
# nasa_gwm_lake_30-day\lake000769.27b.2.txt
# nasa_gwm_lake_30-day\lake000770.27b.2.jpg
# nasa_gwm_lake_30-day\lake000770.27b.2.txt
# nasa_gwm_lake_30-day\lake000772.21d.2.jpg
# nasa_gwm_lake_30-day\lake000772.21d.2.txt
# nasa_gwm_lake_30-day\lake000773.35d.2.jpg
# nasa_gwm_lake_30-day\lake000773.35d.2.txt
# nasa_gwm_lake_30-day\lake000785.27b.2.jpg
# nasa_gwm_lake_30-day\lake000785.27b.2.txt
# nasa_gwm_lake_30-day\lake000787.35d.2.jpg
# nasa_gwm_lake_30-day\lake000787.35d.2.txt
# nasa_gwm_lake_30-day\lake000791.27b.2.jpg
# nasa_gwm_lake_30-day\lake000791.27b.2.txt
# nasa_gwm_lake_30-day\lake000803.27a.2.jpg
# nasa_gwm_lake_30-day\lake000803.27a.2.txt
# nasa_gwm_lake_30-day\lake000850.27a.2.jpg
# nasa_gwm_lake_30-day\lake000850.27a.2.txt
# nasa_gwm_lake_30-day\lake000851.27a.2.jpg
# nasa_gwm_lake_30-day\lake000851.27a.2.txt
# nasa_gwm_lake_30-day\lake000867.27b.2.jpg
# nasa_gwm_lake_30-day\lake000867.27b.2.txt
# nasa_gwm_lake_30-day\lake000870.27b.2.jpg
# nasa_gwm_lake_30-day\lake000870.27b.2.txt
# nasa_gwm_lake_30-day\lake000872.27a.2.jpg
# nasa_gwm_lake_30-day\lake000872.27a.2.txt
# nasa_gwm_lake_30-day\lake000955.35d.2.jpg
# nasa_gwm_lake_30-day\lake000955.35d.2.txt
# nasa_gwm_lake_30-day\lake000966.27b.2.jpg
# nasa_gwm_lake_30-day\lake000966.27b.2.txt
# nasa_gwm_lake_30-day\lake000967.21d.2.jpg
# nasa_gwm_lake_30-day\lake000967.21d.2.txt
# nasa_gwm_lake_30-day\lake000968.21d.2.jpg
# nasa_gwm_lake_30-day\lake000968.21d.2.txt
# nasa_gwm_lake_30-day\lake000969.27b.2.jpg
# nasa_gwm_lake_30-day\lake000969.27b.2.txt
# nasa_gwm_lake_30-day\lake000970.27b.2.jpg
# nasa_gwm_lake_30-day\lake000970.27b.2.txt
# nasa_gwm_lake_30-day\lake000971.27a.2.jpg
# nasa_gwm_lake_30-day\lake000971.27a.2.txt
# nasa_gwm_lake_30-day\lake000973.27a.2.jpg
# nasa_gwm_lake_30-day\lake000973.27a.2.txt
# nasa_gwm_lake_30-day\lake000978.27a.2.jpg
# nasa_gwm_lake_30-day\lake000978.27a.2.txt
# nasa_gwm_lake_30-day\lake001009.27b.2.jpg
# nasa_gwm_lake_30-day\lake001009.27b.2.txt
# nasa_gwm_lake_30-day\lake001061.27b.2.jpg
# nasa_gwm_lake_30-day\lake001061.27b.2.txt
# nasa_gwm_lake_30-day\lake001073.27a.2.jpg
# nasa_gwm_lake_30-day\lake001073.27a.2.txt
# nasa_gwm_lake_30-day\lake001075.27b.2.jpg
# nasa_gwm_lake_30-day\lake001075.27b.2.txt
# nasa_gwm_lake_30-day\lake001150.27a.2.jpg
# nasa_gwm_lake_30-day\lake001150.27a.2.txt
# nasa_gwm_lake_30-day\lake001164.35d.2.jpg
# nasa_gwm_lake_30-day\lake001164.35d.2.txt
# nasa_gwm_lake_30-day\lake001222.27b.2.jpg
# nasa_gwm_lake_30-day\lake001222.27b.2.txt
# nasa_gwm_lake_30-day\lake001244.27b.2.jpg
# nasa_gwm_lake_30-day\lake001244.27b.2.txt
# nasa_gwm_lake_30-day\lake001267.27b.2.jpg
# nasa_gwm_lake_30-day\lake001267.27b.2.txt
# nasa_gwm_lake_30-day\lake001268.27b.2.jpg
# nasa_gwm_lake_30-day\lake001268.27b.2.txt
# nasa_gwm_lake_30-day\lake001273.35d.2.jpg
# nasa_gwm_lake_30-day\lake001273.35d.2.txt
# nasa_gwm_lake_30-day\lake001278.35d.2.jpg
# nasa_gwm_lake_30-day\lake001278.35d.2.txt
# nasa_gwm_lake_30-day\lake001279.35d.2.jpg
# nasa_gwm_lake_30-day\lake001279.35d.2.txt
# nasa_gwm_lake_30-day\lake001287.27b.2.jpg
# nasa_gwm_lake_30-day\lake001287.27b.2.txt
# nasa_gwm_lake_30-day\lake001288.27b.2.jpg
# nasa_gwm_lake_30-day\lake001288.27b.2.txt
# nasa_gwm_lake_30-day\lake001391.27b.2.jpg
# nasa_gwm_lake_30-day\lake001391.27b.2.txt
# nasa_gwm_lake_30-day\lake001392.27b.2.jpg
# nasa_gwm_lake_30-day\lake001392.27b.2.txt
# nasa_gwm_lake_30-day\lake001404.27b.2.jpg
# nasa_gwm_lake_30-day\lake001404.27b.2.txt
# nasa_gwm_lake_30-day\lake001411.27a.2.jpg
# nasa_gwm_lake_30-day\lake001411.27a.2.txt
# nasa_gwm_lake_30-day\lake001411.27b.2.jpg
# nasa_gwm_lake_30-day\lake001411.27b.2.txt
# nasa_gwm_lake_30-day\lake001414.27a.2.jpg
# nasa_gwm_lake_30-day\lake001414.27a.2.txt
# nasa_gwm_lake_30-day\lake001415.27a.2.jpg
# nasa_gwm_lake_30-day\lake001415.27a.2.txt
# nasa_gwm_lake_30-day\lake001432.35d.2.jpg
# nasa_gwm_lake_30-day\lake001432.35d.2.txt
# nasa_gwm_lake_30-day\lake001433.27a.2.jpg
# nasa_gwm_lake_30-day\lake001433.27a.2.txt
# nasa_gwm_lake_30-day\lake001438.27a.2.jpg
# nasa_gwm_lake_30-day\lake001438.27a.2.txt
# nasa_gwm_lake_30-day\lake001452.27a.2.jpg
# nasa_gwm_lake_30-day\lake001452.27a.2.txt
# nasa_gwm_lake_30-day\lake001453.27a.2.jpg
# nasa_gwm_lake_30-day\lake001453.27a.2.txt
# nasa_gwm_lake_30-day\lake001456.27a.2.jpg
# nasa_gwm_lake_30-day\lake001456.27a.2.txt
# nasa_gwm_lake_30-day\lake001457.27b.2.jpg
# nasa_gwm_lake_30-day\lake001457.27b.2.txt
# nasa_gwm_lake_30-day\lake001466.27a.2.jpg
# nasa_gwm_lake_30-day\lake001466.27a.2.txt
# nasa_gwm_lake_30-day\lake001475.27b.2.jpg
# nasa_gwm_lake_30-day\lake001475.27b.2.txt
# nasa_gwm_lake_30-day\lake001478.35d.2.jpg
# nasa_gwm_lake_30-day\lake001478.35d.2.txt
# nasa_gwm_lake_30-day\lake001499.27a.2.jpg
# nasa_gwm_lake_30-day\lake001499.27a.2.txt
# nasa_gwm_lake_30-day\lake001508.27b.2.jpg
# nasa_gwm_lake_30-day\lake001508.27b.2.txt
# nasa_gwm_lake_30-day\lake001518.27b.2.jpg
# nasa_gwm_lake_30-day\lake001518.27b.2.txt
# nasa_gwm_lake_30-day\lake001520.27a.2.jpg
# nasa_gwm_lake_30-day\lake001520.27a.2.txt
# nasa_gwm_lake_30-day\lake001521.27a.2.jpg
# nasa_gwm_lake_30-day\lake001521.27a.2.txt
# nasa_gwm_lake_30-day\lake001538.27b.2.jpg
# nasa_gwm_lake_30-day\lake001538.27b.2.txt
# nasa_gwm_lake_30-day\lake001544.27a.2.jpg
# nasa_gwm_lake_30-day\lake001544.27a.2.txt
# nasa_gwm_lake_30-day\lake001547.35d.2.jpg
# nasa_gwm_lake_30-day\lake001547.35d.2.txt
# nasa_gwm_lake_30-day\lake001556.27b.2.jpg
# nasa_gwm_lake_30-day\lake001556.27b.2.txt
# nasa_gwm_lake_30-day\lake001558.21d.2.jpg
# nasa_gwm_lake_30-day\lake001558.21d.2.txt
# nasa_gwm_lake_30-day\lake001561.27b.2.jpg
# nasa_gwm_lake_30-day\lake001561.27b.2.txt
# nasa_gwm_lake_30-day\lake001565.27b.2.jpg
# nasa_gwm_lake_30-day\lake001565.27b.2.txt
# nasa_gwm_lake_30-day\lake001567.27a.2.jpg
# nasa_gwm_lake_30-day\lake001567.27a.2.txt
# nasa_gwm_lake_30-day\lake001568.35d.2.jpg
# nasa_gwm_lake_30-day\lake001568.35d.2.txt
# nasa_gwm_lake_30-day\lake001572.27b.2.jpg
# nasa_gwm_lake_30-day\lake001572.27b.2.txt
# nasa_gwm_lake_30-day\lake001576.21d.2.jpg
# nasa_gwm_lake_30-day\lake001576.21d.2.txt
# nasa_gwm_lake_30-day\lake001577.35d.2.jpg
# nasa_gwm_lake_30-day\lake001577.35d.2.txt
# nasa_gwm_lake_30-day\lake001578.27b.2.jpg
# nasa_gwm_lake_30-day\lake001578.27b.2.txt
# nasa_gwm_lake_30-day\lake001579.27b.2.jpg
# nasa_gwm_lake_30-day\lake001579.27b.2.txt
# nasa_gwm_lake_30-day\lake001581.27a.2.jpg
# nasa_gwm_lake_30-day\lake001581.27a.2.txt
# nasa_gwm_lake_30-day\lake001583.27a.2.jpg
# nasa_gwm_lake_30-day\lake001583.27a.2.txt
# nasa_gwm_lake_30-day\lake001597.27b.2.jpg
# nasa_gwm_lake_30-day\lake001597.27b.2.txt
# nasa_gwm_lake_30-day\lake001602.35d.2.jpg
# nasa_gwm_lake_30-day\lake001602.35d.2.txt
# nasa_gwm_lake_30-day\lake001603.35d.2.jpg
# nasa_gwm_lake_30-day\lake001603.35d.2.txt
# nasa_gwm_lake_30-day\lake001607.27b.2.jpg
# nasa_gwm_lake_30-day\lake001607.27b.2.txt
# nasa_gwm_lake_30-day\lake001620.21d.2.jpg
# nasa_gwm_lake_30-day\lake001620.21d.2.txt
# nasa_gwm_lake_30-day\lake001625.27b.2.jpg
# nasa_gwm_lake_30-day\lake001625.27b.2.txt
# nasa_gwm_lake_30-day\lake001626.27a.2.jpg
# nasa_gwm_lake_30-day\lake001626.27a.2.txt
# nasa_gwm_lake_30-day\lake001634.27a.2.jpg
# nasa_gwm_lake_30-day\lake001634.27a.2.txt
# nasa_gwm_lake_30-day\lake001636.27b.2.jpg
# nasa_gwm_lake_30-day\lake001636.27b.2.txt
# nasa_gwm_lake_30-day\lake001643.21d.2.jpg
# nasa_gwm_lake_30-day\lake001643.21d.2.txt
# nasa_gwm_lake_30-day\lake001648.27b.2.jpg
# nasa_gwm_lake_30-day\lake001648.27b.2.txt
# nasa_gwm_lake_30-day\lake001654.27b.2.jpg
# nasa_gwm_lake_30-day\lake001654.27b.2.txt
# nasa_gwm_lake_30-day\lake001659.27a.2.jpg
# nasa_gwm_lake_30-day\lake001659.27a.2.txt
# nasa_gwm_lake_30-day\lake001663.27b.2.jpg
# nasa_gwm_lake_30-day\lake001663.27b.2.txt
# nasa_gwm_lake_30-day\lake001678.27b.2.jpg
# nasa_gwm_lake_30-day\lake001678.27b.2.txt
# nasa_gwm_lake_30-day\lake001683.27a.2.jpg
# nasa_gwm_lake_30-day\lake001683.27a.2.txt
# nasa_gwm_lake_30-day\lake001686.27b.2.jpg
# nasa_gwm_lake_30-day\lake001686.27b.2.txt
# nasa_gwm_lake_30-day\lake001690.27b.2.jpg
# nasa_gwm_lake_30-day\lake001690.27b.2.txt
# nasa_gwm_lake_30-day\lake001705.27a.2.jpg
# nasa_gwm_lake_30-day\lake001705.27a.2.txt
# nasa_gwm_lake_30-day\lake001712.35d.2.jpg
# nasa_gwm_lake_30-day\lake001712.35d.2.txt
# nasa_gwm_lake_30-day\lake001716.27b.2.jpg
# nasa_gwm_lake_30-day\lake001716.27b.2.txt
# nasa_gwm_lake_30-day\lake001782.27b.2.jpg
# nasa_gwm_lake_30-day\lake001782.27b.2.txt
# nasa_gwm_lake_30-day\lake001783.27a.2.jpg
# nasa_gwm_lake_30-day\lake001783.27a.2.txt
# nasa_gwm_lake_30-day\lake001785.21d.2.jpg
# nasa_gwm_lake_30-day\lake001785.21d.2.txt
# nasa_gwm_lake_30-day\lake001787.27a.2.jpg
# nasa_gwm_lake_30-day\lake001787.27a.2.txt
# nasa_gwm_lake_30-day\lake001789.27a.2.jpg
# nasa_gwm_lake_30-day\lake001789.27a.2.txt
# nasa_gwm_lake_30-day\lake001803.27a.2.jpg
# nasa_gwm_lake_30-day\lake001803.27a.2.txt
# nasa_gwm_lake_30-day\lake001821.21d.2.jpg
# nasa_gwm_lake_30-day\lake001821.21d.2.txt
# nasa_gwm_lake_30-day\lake001829.27a.2.jpg
# nasa_gwm_lake_30-day\lake001829.27a.2.txt
# nasa_gwm_lake_30-day\lake001830.27a.2.jpg
# nasa_gwm_lake_30-day\lake001830.27a.2.txt
# nasa_gwm_lake_30-day\lake001831.27a.2.jpg
# nasa_gwm_lake_30-day\lake001831.27a.2.txt
# nasa_gwm_lake_30-day\lake001837.27b.2.jpg
# nasa_gwm_lake_30-day\lake001837.27b.2.txt
# nasa_gwm_lake_30-day\lake001839.27b.2.jpg
# nasa_gwm_lake_30-day\lake001839.27b.2.txt
# nasa_gwm_lake_30-day\lake001841.27b.2.jpg
# nasa_gwm_lake_30-day\lake001841.27b.2.txt
# nasa_gwm_lake_30-day\lake001845.21d.2.jpg
# nasa_gwm_lake_30-day\lake001845.21d.2.txt
# nasa_gwm_lake_30-day\lake001848.27a.2.jpg
# nasa_gwm_lake_30-day\lake001848.27a.2.txt
# nasa_gwm_lake_30-day\lake001854.27a.2.jpg
# nasa_gwm_lake_30-day\lake001854.27a.2.txt
# nasa_gwm_lake_30-day\lake001859.27b.2.jpg
# nasa_gwm_lake_30-day\lake001859.27b.2.txt
# nasa_gwm_lake_30-day\lake001861.35d.2.jpg
# nasa_gwm_lake_30-day\lake001861.35d.2.txt
# nasa_gwm_lake_30-day\lake001862.27b.2.jpg
# nasa_gwm_lake_30-day\lake001862.27b.2.txt
# nasa_gwm_lake_30-day\lake001866.27b.2.jpg
# nasa_gwm_lake_30-day\lake001866.27b.2.txt
# nasa_gwm_lake_30-day\lake001902.21d.2.jpg
# nasa_gwm_lake_30-day\lake001902.21d.2.txt
# nasa_gwm_lake_30-day\lake001905.35d.2.jpg
# nasa_gwm_lake_30-day\lake001905.35d.2.txt
# nasa_gwm_lake_30-day\lake001922.35d.2.jpg
# nasa_gwm_lake_30-day\lake001922.35d.2.txt
# nasa_gwm_lake_30-day\lake001953.27a.2.jpg
# nasa_gwm_lake_30-day\lake001953.27a.2.txt
# nasa_gwm_lake_30-day\lake002007.27b.2.jpg
# nasa_gwm_lake_30-day\lake002007.27b.2.txt
# nasa_gwm_lake_30-day\lake002146.27a.2.jpg
# nasa_gwm_lake_30-day\lake002146.27a.2.txt
# nasa_gwm_lake_30-day\lake002254.27a.2.jpg
# nasa_gwm_lake_30-day\lake002254.27a.2.txt
# nasa_gwm_lake_30-day\lake002280.35d.2.jpg
# nasa_gwm_lake_30-day\lake002280.35d.2.txt
# nasa_gwm_lake_30-day\lake002286.27b.2.jpg
# nasa_gwm_lake_30-day\lake002286.27b.2.txt
# nasa_gwm_lake_30-day\lake002288.27b.2.jpg
# nasa_gwm_lake_30-day\lake002288.27b.2.txt
# nasa_gwm_lake_30-day\lake002296.27b.2.jpg
# nasa_gwm_lake_30-day\lake002296.27b.2.txt
# nasa_gwm_lake_30-day\lake002310.27b.2.jpg
# nasa_gwm_lake_30-day\lake002310.27b.2.txt
# nasa_gwm_lake_30-day\lake002326.27a.2.jpg
# nasa_gwm_lake_30-day\lake002326.27a.2.txt
# nasa_gwm_lake_30-day\lake002328.35d.2.jpg
# nasa_gwm_lake_30-day\lake002328.35d.2.txt
# nasa_gwm_lake_30-day\lake002329.35d.2.jpg
# nasa_gwm_lake_30-day\lake002329.35d.2.txt
# nasa_gwm_lake_30-day\lake003118.27a.2.jpg
# nasa_gwm_lake_30-day\lake003118.27a.2.txt
# nasa_gwm_lake_30-day\lake003564.27a.2.jpg
# nasa_gwm_lake_30-day\lake003564.27a.2.txt
# nasa_gwm_lake_30-day\lake003685.27b.2.jpg
# nasa_gwm_lake_30-day\lake003685.27b.2.txt
# nasa_gwm_lake_30-day\lake003824.27b.2.jpg
# nasa_gwm_lake_30-day\lake003824.27b.2.txt
# nasa_gwm_lake_30-day\lake003902.27a.2.jpg
# nasa_gwm_lake_30-day\lake003902.27a.2.txt
# nasa_gwm_lake_30-day\lake003908.35d.2.jpg
# nasa_gwm_lake_30-day\lake003908.35d.2.txt
# nasa_gwm_lake_30-day\lake003909.27a.2.jpg
# nasa_gwm_lake_30-day\lake003909.27a.2.txt
# nasa_gwm_lake_30-day\lake003910.35d.2.jpg
# nasa_gwm_lake_30-day\lake003910.35d.2.txt
# nasa_gwm_lake_30-day\lake003914.27b.2.jpg
# nasa_gwm_lake_30-day\lake003914.27b.2.txt
# nasa_gwm_lake_30-day\lake003916.27a.2.jpg
# nasa_gwm_lake_30-day\lake003916.27a.2.txt
# nasa_gwm_lake_30-day\lake003917.27a.2.jpg
# nasa_gwm_lake_30-day\lake003917.27a.2.txt
# nasa_gwm_lake_30-day\lake003920.27b.2.jpg
# nasa_gwm_lake_30-day\lake003920.27b.2.txt
# nasa_gwm_lake_30-day\lake003924.27a.2.jpg
# nasa_gwm_lake_30-day\lake003924.27a.2.txt
# nasa_gwm_lake_30-day\lake003946.27b.2.jpg
# nasa_gwm_lake_30-day\lake003946.27b.2.txt
# nasa_gwm_lake_30-day\lake003947.27b.2.jpg
# nasa_gwm_lake_30-day\lake003947.27b.2.txt
# nasa_gwm_lake_30-day\lake003949.27a.2.jpg
# nasa_gwm_lake_30-day\lake003949.27a.2.txt
# nasa_gwm_lake_30-day\lake003965.27b.2.jpg
# nasa_gwm_lake_30-day\lake003965.27b.2.txt
# nasa_gwm_lake_30-day\lake003969.27a.2.jpg
# nasa_gwm_lake_30-day\lake003969.27a.2.txt
# nasa_gwm_lake_30-day\lake003977.27a.2.jpg
# nasa_gwm_lake_30-day\lake003977.27a.2.txt
# nasa_gwm_lake_30-day\lake004107.27b.2.jpg
# nasa_gwm_lake_30-day\lake004107.27b.2.txt
# nasa_gwm_lake_30-day\lake004110.27a.2.jpg
# nasa_gwm_lake_30-day\lake004110.27a.2.txt
# nasa_gwm_lake_30-day\lake004190.35d.2.jpg
# nasa_gwm_lake_30-day\lake004190.35d.2.txt
# nasa_gwm_lake_30-day\lake004286.35d.2.jpg
# nasa_gwm_lake_30-day\lake004286.35d.2.txt
# nasa_gwm_lake_30-day\lake004303.27a.2.jpg
# nasa_gwm_lake_30-day\lake004303.27a.2.txt
# nasa_gwm_lake_30-day\lake004324.27b.2.jpg
# nasa_gwm_lake_30-day\lake004324.27b.2.txt
# nasa_gwm_lake_30-day\lake004472.27a.2.jpg
# nasa_gwm_lake_30-day\lake004472.27a.2.txt
# nasa_gwm_lake_30-day\lake004629.27b.2.jpg
# nasa_gwm_lake_30-day\lake004629.27b.2.txt
# nasa_gwm_lake_30-day\lake004649.27a.2.jpg
# nasa_gwm_lake_30-day\lake004649.27a.2.txt
# nasa_gwm_lake_30-day\lake004656.27a.2.jpg
# nasa_gwm_lake_30-day\lake004656.27a.2.txt
# nasa_gwm_lake_30-day\lake004701.27a.2.jpg
# nasa_gwm_lake_30-day\lake004701.27a.2.txt
# nasa_gwm_lake_30-day\lake004750.27b.2.jpg
# nasa_gwm_lake_30-day\lake004750.27b.2.txt
# nasa_gwm_lake_30-day\lake004845.27b.2.jpg
# nasa_gwm_lake_30-day\lake004845.27b.2.txt
# nasa_gwm_lake_30-day\lake004901.27b.2.jpg
# nasa_gwm_lake_30-day\lake004901.27b.2.txt
# nasa_gwm_lake_30-day\lake005041.27b.2.jpg
# nasa_gwm_lake_30-day\lake005041.27b.2.txt
# nasa_gwm_lake_30-day\lake005225.27b.2.jpg
# nasa_gwm_lake_30-day\lake005225.27b.2.txt
# nasa_gwm_lake_30-day\lake005360.21d.2.jpg
# nasa_gwm_lake_30-day\lake005360.21d.2.txt
# nasa_gwm_lake_30-day\lake005417.27b.2.jpg
# nasa_gwm_lake_30-day\lake005417.27b.2.txt
# nasa_gwm_lake_30-day\lake005529.27a.2.jpg
# nasa_gwm_lake_30-day\lake005529.27a.2.txt
# nasa_gwm_lake_30-day\lake005656.27b.2.jpg
# nasa_gwm_lake_30-day\lake005656.27b.2.txt
# nasa_gwm_lake_30-day\lake005731.27a.2.jpg
# nasa_gwm_lake_30-day\lake005731.27a.2.txt
# nasa_gwm_lake_30-day\lake005772.27b.2.jpg
# nasa_gwm_lake_30-day\lake005772.27b.2.txt
# nasa_gwm_lake_30-day\lake005791.27b.2.jpg
# nasa_gwm_lake_30-day\lake005791.27b.2.txt
# nasa_gwm_lake_30-day\lake005792.27a.2.jpg
# nasa_gwm_lake_30-day\lake005792.27a.2.txt
# nasa_gwm_lake_30-day\lake005794.27a.2.jpg
# nasa_gwm_lake_30-day\lake005794.27a.2.txt
# nasa_gwm_lake_30-day\lake005821.27a.2.jpg
# nasa_gwm_lake_30-day\lake005821.27a.2.txt
# nasa_gwm_lake_30-day\lake005827.27b.2.jpg
# nasa_gwm_lake_30-day\lake005827.27b.2.txt
# nasa_gwm_lake_30-day\lake005858.27b.2.jpg
# nasa_gwm_lake_30-day\lake005858.27b.2.txt
# nasa_gwm_lake_30-day\lake005869.27b.2.jpg
# nasa_gwm_lake_30-day\lake005869.27b.2.txt
# nasa_gwm_lake_30-day\lake005890.27b.2.jpg
# nasa_gwm_lake_30-day\lake005890.27b.2.txt
# nasa_gwm_lake_30-day\lake005971.27b.2.jpg
# nasa_gwm_lake_30-day\lake005971.27b.2.txt
# nasa_gwm_lake_30-day\lake005974.27b.2.jpg
# nasa_gwm_lake_30-day\lake005974.27b.2.txt
# nasa_gwm_lake_30-day\lake005992.35d.2.jpg
# nasa_gwm_lake_30-day\lake005992.35d.2.txt
# nasa_gwm_lake_30-day\lake006000.27a.2.jpg
# nasa_gwm_lake_30-day\lake006000.27a.2.txt
# nasa_gwm_lake_30-day\lake006031.27a.2.jpg
# nasa_gwm_lake_30-day\lake006031.27a.2.txt
# nasa_gwm_lake_30-day\lake006034.27a.2.jpg
# nasa_gwm_lake_30-day\lake006034.27a.2.txt
# nasa_gwm_lake_30-day\lake006035.27b.2.jpg
# nasa_gwm_lake_30-day\lake006035.27b.2.txt
# nasa_gwm_lake_30-day\lake006039.27b.2.jpg
# nasa_gwm_lake_30-day\lake006039.27b.2.txt
# nasa_gwm_lake_30-day\lake006041.27a.2.jpg
# nasa_gwm_lake_30-day\lake006041.27a.2.txt
# nasa_gwm_lake_30-day\lake006043.27a.2.jpg
# nasa_gwm_lake_30-day\lake006043.27a.2.txt
# nasa_gwm_lake_30-day\lake006049.27a.2.jpg
# nasa_gwm_lake_30-day\lake006049.27a.2.txt
# nasa_gwm_lake_30-day\lake006056.27a.2.jpg
# nasa_gwm_lake_30-day\lake006056.27a.2.txt
# nasa_gwm_lake_30-day\lake006059.27b.2.jpg
# nasa_gwm_lake_30-day\lake006059.27b.2.txt
# nasa_gwm_lake_30-day\lake006060.27b.2.jpg
# nasa_gwm_lake_30-day\lake006060.27b.2.txt
# nasa_gwm_lake_30-day\lake006061.27b.2.jpg
# nasa_gwm_lake_30-day\lake006061.27b.2.txt
# nasa_gwm_lake_30-day\lake006063.27a.2.jpg
# nasa_gwm_lake_30-day\lake006063.27a.2.txt
# nasa_gwm_lake_30-day\lake006066.27a.2.jpg
# nasa_gwm_lake_30-day\lake006066.27a.2.txt
# nasa_gwm_lake_30-day\lake006067.27a.2.jpg
# nasa_gwm_lake_30-day\lake006067.27a.2.txt
# nasa_gwm_lake_30-day\lake006076.27a.2.jpg
# nasa_gwm_lake_30-day\lake006076.27a.2.txt
# nasa_gwm_lake_30-day\lake006079.27b.2.jpg
# nasa_gwm_lake_30-day\lake006079.27b.2.txt
# nasa_gwm_lake_30-day\lake006086.27b.2.jpg
# nasa_gwm_lake_30-day\lake006086.27b.2.txt
# nasa_gwm_lake_30-day\lake006155.27b.2.jpg
# nasa_gwm_lake_30-day\lake006155.27b.2.txt
# nasa_gwm_lake_30-day\lake006165.27b.2.jpg
# nasa_gwm_lake_30-day\lake006165.27b.2.txt
# nasa_gwm_lake_30-day\lake006166.27b.2.jpg
# nasa_gwm_lake_30-day\lake006166.27b.2.txt
# nasa_gwm_lake_30-day\lake006167.27b.2.jpg
# nasa_gwm_lake_30-day\lake006167.27b.2.txt
# nasa_gwm_lake_30-day\lake006168.27b.2.jpg
# nasa_gwm_lake_30-day\lake006168.27b.2.txt
# nasa_gwm_lake_30-day\lake006216.27b.2.jpg
# nasa_gwm_lake_30-day\lake006216.27b.2.txt
# nasa_gwm_lake_30-day\lake006256.27b.2.jpg
# nasa_gwm_lake_30-day\lake006256.27b.2.txt
# nasa_gwm_lake_30-day\lake006266.27b.2.jpg
# nasa_gwm_lake_30-day\lake006266.27b.2.txt
# nasa_gwm_lake_30-day\lake006360.27a.2.jpg
# nasa_gwm_lake_30-day\lake006360.27a.2.txt
# nasa_gwm_lake_30-day\lake006525.27a.2.jpg
# nasa_gwm_lake_30-day\lake006525.27a.2.txt
# nasa_gwm_lake_30-day\lake006873.27a.2.jpg
# nasa_gwm_lake_30-day\lake006873.27a.2.txt
# nasa_gwm_lake_30-day\lake006878.27a.2.jpg
# nasa_gwm_lake_30-day\lake006878.27a.2.txt
# nasa_gwm_lake_30-day\lake006893.27a.2.jpg
# nasa_gwm_lake_30-day\lake006893.27a.2.txt
# nasa_gwm_lake_30-day\lake006926.27a.2.jpg
# nasa_gwm_lake_30-day\lake006926.27a.2.txt
# nasa_gwm_lake_30-day\lake006983.27a.2.jpg
# nasa_gwm_lake_30-day\lake006983.27a.2.txt
# nasa_gwm_lake_30-day\lake006985.27a.2.jpg
# nasa_gwm_lake_30-day\lake006985.27a.2.txt
# nasa_gwm_lake_30-day\lake006987.27b.2.jpg
# nasa_gwm_lake_30-day\lake006987.27b.2.txt
# nasa_gwm_lake_30-day\lake006988.27a.2.jpg
# nasa_gwm_lake_30-day\lake006988.27a.2.txt
# nasa_gwm_lake_30-day\lake006989.27b.2.jpg
# nasa_gwm_lake_30-day\lake006989.27b.2.txt
# nasa_gwm_lake_30-day\lake006992.27a.2.jpg
# nasa_gwm_lake_30-day\lake006992.27a.2.txt
# nasa_gwm_lake_30-day\lake006995.27a.2.jpg
# nasa_gwm_lake_30-day\lake006995.27a.2.txt
# nasa_gwm_lake_30-day\lake006998.27b.2.jpg
# nasa_gwm_lake_30-day\lake006998.27b.2.txt
# nasa_gwm_lake_30-day\lake007000.27a.2.jpg
# nasa_gwm_lake_30-day\lake007000.27a.2.txt
# nasa_gwm_lake_30-day\lake007003.27a.2.jpg
# nasa_gwm_lake_30-day\lake007003.27a.2.txt
# nasa_gwm_lake_30-day\lake007005.27b.2.jpg
# nasa_gwm_lake_30-day\lake007005.27b.2.txt
# nasa_gwm_lake_30-day\lake007102.27b.2.jpg
# nasa_gwm_lake_30-day\lake007102.27b.2.txt
# nasa_gwm_lake_30-day\lake007104.21d.2.jpg
# nasa_gwm_lake_30-day\lake007104.21d.2.txt
# nasa_gwm_lake_30-day\lake007105.27b.2.jpg
# nasa_gwm_lake_30-day\lake007105.27b.2.txt
# nasa_gwm_lake_30-day\lake007115.27a.2.jpg
# nasa_gwm_lake_30-day\lake007115.27a.2.txt
# nasa_gwm_lake_30-day\lake007117.27b.2.jpg
# nasa_gwm_lake_30-day\lake007117.27b.2.txt
# nasa_gwm_lake_30-day\lake007147.27a.2.jpg
# nasa_gwm_lake_30-day\lake007147.27a.2.txt
# nasa_gwm_lake_30-day\lake007148.27b.2.jpg
# nasa_gwm_lake_30-day\lake007148.27b.2.txt
# nasa_gwm_lake_30-day\lake007151.27a.2.jpg
# nasa_gwm_lake_30-day\lake007151.27a.2.txt
# nasa_gwm_lake_30-day\lake007283.27b.2.jpg
# nasa_gwm_lake_30-day\lake007283.27b.2.txt
# nasa_gwm_lake_30-day\lake007285.27b.2.jpg
# nasa_gwm_lake_30-day\lake007285.27b.2.txt
# nasa_gwm_lake_30-day\lake007286.27a.2.jpg
# nasa_gwm_lake_30-day\lake007286.27a.2.txt
# nasa_gwm_lake_30-day\lake007290.27a.2.jpg
# nasa_gwm_lake_30-day\lake007290.27a.2.txt
# nasa_gwm_lake_30-day\lake007293.27b.2.jpg
# nasa_gwm_lake_30-day\lake007293.27b.2.txt
# nasa_gwm_lake_30-day\lake007309.27a.2.jpg
# nasa_gwm_lake_30-day\lake007309.27a.2.txt
# nasa_gwm_lake_30-day\lake010066.27a.2.jpg
# nasa_gwm_lake_30-day\lake010066.27a.2.txt
# nasa_gwm_lake_30-day\lake100037.27a.2.jpg
# nasa_gwm_lake_30-day\lake100037.27a.2.txt
# nasa_gwm_lake_30-day\lake100051.27a.2.jpg
# nasa_gwm_lake_30-day\lake100051.27a.2.txt
# nasa_gwm_lake_30-day\lake100067.27a.2.jpg
# nasa_gwm_lake_30-day\lake100067.27a.2.txt
# nasa_gwm_lake_30-day\lake100073.27b.2.jpg
# nasa_gwm_lake_30-day\lake100073.27b.2.txt
# nasa_gwm_lake_30-day\lake100079.27a.2.jpg
# nasa_gwm_lake_30-day\lake100079.27a.2.txt
# nasa_gwm_lake_30-day\lake100097.27a.2.jpg
# nasa_gwm_lake_30-day\lake100097.27a.2.txt
# nasa_gwm_lake_30-day\lake100110.27b.2.jpg
# nasa_gwm_lake_30-day\lake100110.27b.2.txt
# nasa_gwm_lake_30-day\lake100121.27a.2.jpg
# nasa_gwm_lake_30-day\lake100121.27a.2.txt
# nasa_gwm_lake_30-day\lake100371.27b.2.jpg
# nasa_gwm_lake_30-day\lake100371.27b.2.txt
# nasa_gwm_lake_30-day\lake100387.27b.2.jpg
# nasa_gwm_lake_30-day\lake100387.27b.2.txt
# nasa_gwm_lake_30-day\lake100403.27a.2.jpg
# nasa_gwm_lake_30-day\lake100403.27a.2.txt
# nasa_gwm_lake_30-day\lake100461.35d.2.jpg
# nasa_gwm_lake_30-day\lake100461.35d.2.txt
# nasa_gwm_lake_30-day\lake100496.27b.2.jpg
# nasa_gwm_lake_30-day\lake100496.27b.2.txt
# nasa_gwm_lake_30-day\lake100590.27a.2.jpg
# nasa_gwm_lake_30-day\lake100590.27a.2.txt
# nasa_gwm_lake_30-day\lake100612.27b.2.jpg
# nasa_gwm_lake_30-day\lake100612.27b.2.txt
# nasa_gwm_lake_30-day\lake100625.27a.2.jpg
# nasa_gwm_lake_30-day\lake100625.27a.2.txt
# nasa_gwm_lake_30-day\lake100718.27b.2.jpg
# nasa_gwm_lake_30-day\lake100718.27b.2.txt
# nasa_gwm_lake_30-day\lake100773.27b.2.jpg
# nasa_gwm_lake_30-day\lake100773.27b.2.txt
# nasa_gwm_lake_30-day\lake100798.27a.2.jpg
# nasa_gwm_lake_30-day\lake100798.27a.2.txt
# nasa_gwm_lake_30-day\lake100837.27b.2.jpg
# nasa_gwm_lake_30-day\lake100837.27b.2.txt
# nasa_gwm_lake_30-day\lake100862.27a.2.jpg
# nasa_gwm_lake_30-day\lake100862.27a.2.txt
# nasa_gwm_lake_30-day\lake100873.27a.2.jpg
# nasa_gwm_lake_30-day\lake100873.27a.2.txt
# nasa_gwm_lake_30-day\lake100903.27a.2.jpg
# nasa_gwm_lake_30-day\lake100903.27a.2.txt
# nasa_gwm_lake_30-day\lake100958.27a.2.jpg
# nasa_gwm_lake_30-day\lake100958.27a.2.txt
# nasa_gwm_lake_30-day\lake101073.27b.2.jpg
# nasa_gwm_lake_30-day\lake101073.27b.2.txt
# nasa_gwm_lake_30-day\lake101121.27a.2.jpg
# nasa_gwm_lake_30-day\lake101121.27a.2.txt
# nasa_gwm_lake_30-day\lake101265.27a.2.jpg
# nasa_gwm_lake_30-day\lake101265.27a.2.txt
# nasa_gwm_lake_30-day\lake101296.27b.2.jpg
# nasa_gwm_lake_30-day\lake101296.27b.2.txt
# nasa_gwm_lake_30-day\lake101411.27a.2.jpg
# nasa_gwm_lake_30-day\lake101411.27a.2.txt
# nasa_gwm_lake_30-day\lake101432.27a.2.jpg
# nasa_gwm_lake_30-day\lake101432.27a.2.txt
# nasa_gwm_lake_30-day\lake101436.27a.2.jpg
# nasa_gwm_lake_30-day\lake101436.27a.2.txt
# nasa_gwm_lake_30-day\lake101437.35d.2.jpg
# nasa_gwm_lake_30-day\lake101437.35d.2.txt
# nasa_gwm_lake_30-day\lake101438.35d.2.jpg
# nasa_gwm_lake_30-day\lake101438.35d.2.txt
# nasa_gwm_lake_30-day\lake101448.27b.2.jpg
# nasa_gwm_lake_30-day\lake101448.27b.2.txt
# nasa_gwm_lake_30-day\lake101462.27a.2.jpg
# nasa_gwm_lake_30-day\lake101462.27a.2.txt
# nasa_gwm_lake_30-day\lake101495.35d.2.jpg
# nasa_gwm_lake_30-day\lake101495.35d.2.txt
# nasa_gwm_lake_30-day\lake101500.27a.2.jpg
# nasa_gwm_lake_30-day\lake101500.27a.2.txt
# nasa_gwm_lake_30-day\lake101503.27a.2.jpg
# nasa_gwm_lake_30-day\lake101503.27a.2.txt
# nasa_gwm_lake_30-day\lake101508.21d.2.jpg
# nasa_gwm_lake_30-day\lake101508.21d.2.txt
# nasa_gwm_lake_30-day\lake101534.27b.2.jpg
# nasa_gwm_lake_30-day\lake101534.27b.2.txt
# nasa_gwm_lake_30-day\lake101538.27b.2.jpg
# nasa_gwm_lake_30-day\lake101538.27b.2.txt
# nasa_gwm_lake_30-day\lake101598.27a.2.jpg
# nasa_gwm_lake_30-day\lake101598.27a.2.txt
# nasa_gwm_lake_30-day\lake101603.27b.2.jpg
# nasa_gwm_lake_30-day\lake101603.27b.2.txt
# nasa_gwm_lake_30-day\lake101607.27a.2.jpg
# nasa_gwm_lake_30-day\lake101607.27a.2.txt
# nasa_gwm_lake_30-day\lake101619.27a.2.jpg
# nasa_gwm_lake_30-day\lake101619.27a.2.txt
# nasa_gwm_lake_30-day\lake101710.27a.2.jpg
# nasa_gwm_lake_30-day\lake101710.27a.2.txt
# nasa_gwm_lake_30-day\lake101753.27a.2.jpg
# nasa_gwm_lake_30-day\lake101753.27a.2.txt
# nasa_gwm_lake_30-day\lake101792.27a.2.jpg
# nasa_gwm_lake_30-day\lake101792.27a.2.txt
# nasa_gwm_lake_30-day\lake101796.27a.2.jpg
# nasa_gwm_lake_30-day\lake101796.27a.2.txt
# nasa_gwm_lake_30-day\lake101848.27a.2.jpg
# nasa_gwm_lake_30-day\lake101848.27a.2.txt
# nasa_gwm_lake_30-day\lake101878.27a.2.jpg
# nasa_gwm_lake_30-day\lake101878.27a.2.txt
# nasa_gwm_lake_30-day\lake101905.27b.2.jpg
# nasa_gwm_lake_30-day\lake101905.27b.2.txt
# nasa_gwm_lake_30-day\lake101922.27b.2.jpg
# nasa_gwm_lake_30-day\lake101922.27b.2.txt
# nasa_gwm_lake_30-day\lake101979.27a.2.jpg
# nasa_gwm_lake_30-day\lake101979.27a.2.txt
# nasa_gwm_lake_30-day\lake102068.27b.2.jpg
# nasa_gwm_lake_30-day\lake102068.27b.2.txt
# nasa_gwm_lake_30-day\lake102254.27b.2.jpg
# nasa_gwm_lake_30-day\lake102254.27b.2.txt
# nasa_gwm_lake_30-day\lake102292.27b.2.jpg
# nasa_gwm_lake_30-day\lake102292.27b.2.txt
# nasa_gwm_lake_30-day\lake102301.27a.2.jpg
# nasa_gwm_lake_30-day\lake102301.27a.2.txt
# nasa_gwm_lake_30-day\lake102310.21d.2.jpg
# nasa_gwm_lake_30-day\lake102310.21d.2.txt
# nasa_gwm_lake_30-day\lake102326.27a.2.jpg
# nasa_gwm_lake_30-day\lake102326.27a.2.txt
# nasa_gwm_lake_30-day\lake102326.27b.2.jpg
# nasa_gwm_lake_30-day\lake102326.27b.2.txt
# nasa_gwm_lake_30-day\lake102328.27b.2.jpg
# nasa_gwm_lake_30-day\lake102328.27b.2.txt
# nasa_gwm_lake_30-day\lake102329.27b.2.jpg
# nasa_gwm_lake_30-day\lake102329.27b.2.txt
# nasa_gwm_lake_30-day\lake103885.27b.2.jpg
# nasa_gwm_lake_30-day\lake103885.27b.2.txt
# nasa_gwm_lake_30-day\lake103906.27b.2.jpg
# nasa_gwm_lake_30-day\lake103906.27b.2.txt
# nasa_gwm_lake_30-day\lake103909.27b.2.jpg
# nasa_gwm_lake_30-day\lake103909.27b.2.txt
# nasa_gwm_lake_30-day\lake103913.27b.2.jpg
# nasa_gwm_lake_30-day\lake103913.27b.2.txt
# nasa_gwm_lake_30-day\lake103917.27a.2.jpg
# nasa_gwm_lake_30-day\lake103917.27a.2.txt
# nasa_gwm_lake_30-day\lake103967.27b.2.jpg
# nasa_gwm_lake_30-day\lake103967.27b.2.txt
# nasa_gwm_lake_30-day\lake104033.27a.2.jpg
# nasa_gwm_lake_30-day\lake104033.27a.2.txt
# nasa_gwm_lake_30-day\lake104386.27b.2.jpg
# nasa_gwm_lake_30-day\lake104386.27b.2.txt
# nasa_gwm_lake_30-day\lake104556.27b.2.jpg
# nasa_gwm_lake_30-day\lake104556.27b.2.txt
# nasa_gwm_lake_30-day\lake104649.21d.2.jpg
# nasa_gwm_lake_30-day\lake104649.21d.2.txt
# nasa_gwm_lake_30-day\lake104819.27a.2.jpg
# nasa_gwm_lake_30-day\lake104819.27a.2.txt
# nasa_gwm_lake_30-day\lake104945.27b.2.jpg
# nasa_gwm_lake_30-day\lake104945.27b.2.txt
# nasa_gwm_lake_30-day\lake105360.27b.2.jpg
# nasa_gwm_lake_30-day\lake105360.27b.2.txt
# nasa_gwm_lake_30-day\lake105560.27a.2.jpg
# nasa_gwm_lake_30-day\lake105560.27a.2.txt
# nasa_gwm_lake_30-day\lake105656.21d.2.jpg
# nasa_gwm_lake_30-day\lake105656.21d.2.txt
# nasa_gwm_lake_30-day\lake106217.27a.2.jpg
# nasa_gwm_lake_30-day\lake106217.27a.2.txt
# nasa_gwm_lake_30-day\lake106256.27b.2.jpg
# nasa_gwm_lake_30-day\lake106256.27b.2.txt
# nasa_gwm_lake_30-day\lake106893.27b.2.jpg
# nasa_gwm_lake_30-day\lake106893.27b.2.txt
# nasa_gwm_lake_30-day\lake106897.27b.2.jpg
# nasa_gwm_lake_30-day\lake106897.27b.2.txt
# nasa_gwm_lake_30-day\lake106926.21d.2.jpg
# nasa_gwm_lake_30-day\lake106926.21d.2.txt
# nasa_gwm_lake_30-day\lake106984.27a.2.jpg
# nasa_gwm_lake_30-day\lake106984.27a.2.txt
# nasa_gwm_lake_30-day\lake107154.27a.2.jpg
# nasa_gwm_lake_30-day\lake107154.27a.2.txt
# nasa_gwm_lake_30-day\lake110159.27b.2.jpg
# nasa_gwm_lake_30-day\lake110159.27b.2.txt
# nasa_gwm_lake_30-day\lake200097.27b.2.jpg
# nasa_gwm_lake_30-day\lake200097.27b.2.txt
# nasa_gwm_lake_30-day\lake200461.27b.2.jpg
# nasa_gwm_lake_30-day\lake200461.27b.2.txt
# nasa_gwm_lake_30-day\lake200873.27b.2.jpg
# nasa_gwm_lake_30-day\lake200873.27b.2.txt
# nasa_gwm_lake_30-day\lake201121.27b.2.jpg
# nasa_gwm_lake_30-day\lake201121.27b.2.txt
# nasa_gwm_lake_30-day\lake201150.27a.2.jpg
# nasa_gwm_lake_30-day\lake201150.27a.2.txt
# nasa_gwm_lake_30-day\lake201265.27a.2.jpg
# nasa_gwm_lake_30-day\lake201265.27a.2.txt
# nasa_gwm_lake_30-day\lake201296.27b.2.jpg
# nasa_gwm_lake_30-day\lake201296.27b.2.txt
# nasa_gwm_lake_30-day\lake201302.27b.2.jpg
# nasa_gwm_lake_30-day\lake201302.27b.2.txt
# nasa_gwm_lake_30-day\lake201396.27a.2.jpg
# nasa_gwm_lake_30-day\lake201396.27a.2.txt
# nasa_gwm_lake_30-day\lake201437.27a.2.jpg
# nasa_gwm_lake_30-day\lake201437.27a.2.txt
# nasa_gwm_lake_30-day\lake201438.27b.2.jpg
# nasa_gwm_lake_30-day\lake201438.27b.2.txt
# nasa_gwm_lake_30-day\lake202301.27b.2.jpg
# nasa_gwm_lake_30-day\lake202301.27b.2.txt
# nasa_gwm_lake_30-day\lake202326.21d.2.jpg
# nasa_gwm_lake_30-day\lake202326.21d.2.txt
# nasa_gwm_lake_30-day\lake203885.27a.2.jpg
# nasa_gwm_lake_30-day\lake203885.27a.2.txt
# nasa_gwm_lake_30-day\lake204819.27b.2.jpg
# nasa_gwm_lake_30-day\lake204819.27b.2.txt
# nasa_gwm_lake_30-day\lake206217.27b.2.jpg
# nasa_gwm_lake_30-day\lake206217.27b.2.txt
# nasa_gwm_lake_30-day\lake300873.27b.2.jpg
# nasa_gwm_lake_30-day\lake300873.27b.2.txt
# nasa_gwm_lake_30-day\lake301296.27a.2.jpg
# nasa_gwm_lake_30-day\lake301296.27a.2.txt
# nasa_gwm_lake_30-day\lake301437.27b.2.jpg
# nasa_gwm_lake_30-day\lake301437.27b.2.txt
# nasa_gwm_lake_30-day\lake400873.27a.2.jpg
# nasa_gwm_lake_30-day\lake400873.27a.2.txt
# nasa_gwm_lake_30-day\lake401296.21d.2.jpg
# nasa_gwm_lake_30-day\lake401296.21d.2.txt
#
# Preview (first TXT file):
#
# File: nasa_gwm_lake_30-day\lake000004.27a.2.txt
#
# S3A.3.1                    : Data Processing Version ID
# 000004 Edward              : Target database id number and name
#   -0.389   29.540          : Latitude and longitude (degrees East) of target mid-point
#   -0.151   -0.627          : Latitude range of pass traversing target at which data is accepted
#   70       35              : Satellite pass and revolution number designation
#           104              : Reference pass derived from Sentinel-3A cycle #
#             1              : Reference pass retracker selection (ocean=0, ice=1)
#   N/A                      : N/A Bias
#   N/A                      : N/A Bias
#   N/A                      : N/A Bias
